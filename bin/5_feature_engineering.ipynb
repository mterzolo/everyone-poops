# %%
import pandas as pd
import numpy as np

block_meta = pd.read_csv('..//data//created//block_meta.csv')

data = pd.read_hdf('..//data//model//model_data_6H.h5')
data.drop('CaseID', axis = 1, inplace = True)

data['has_poop'] = data['poop'].groupby(data['block_fips']).transform('sum')
data = data[data['has_poop']>0]

block_neigh = pd.read_csv('..//data//created//block_neigh.csv')
block_neigh = block_neigh[block_neigh['nbrhood_name'].notnull()]
block_neigh = block_neigh.loc[:,[
    
    'block_fips',
    'nbrhood_name'
]]

# %%
data = data.merge(block_neigh, on = 'block_fips')

data['Opened_rnd'] = pd.to_datetime(data['Opened_rnd'], format="%Y-%m-%d %H:%M:%S")
data['day_of_week'] = data['Opened_rnd'].dt.dayofweek
data['month'] = data['Opened_rnd'].dt.month
data['hour'] = data['Opened_rnd'].dt.hour

data['winter'] = np.where(data['month'].isin([1, 2, 3]), 1, 0)
data['spring'] = np.where(data['month'].isin([4, 5, 6]), 1, 0)
data['summer'] = np.where(data['month'].isin([7, 8, 9]), 1, 0)
data['fall'] = np.where(data['month'].isin([10, 11, 12]), 1, 0)

# %%
neigh_dummies = pd.get_dummies(data['nbrhood_name'])
data = pd.concat((data,neigh_dummies), axis=1)
del neigh_dummies

month_dummies = pd.get_dummies(data['month'], prefix='month')
data = pd.concat((data,month_dummies), axis=1)
del month_dummies

hour_dummies = pd.get_dummies(data['hour'], prefix='hour')
data = pd.concat((data,hour_dummies), axis=1)
del hour_dummies

dow_dummies = pd.get_dummies(data['day_of_week'], prefix='dow')
data = pd.concat((data,dow_dummies), axis=1)
del dow_dummies

# %%
data = data.merge(block_meta, on='block_fips')

# %%
data[['nbrhood_name','poop']].groupby('nbrhood_name').mean().sort_values('poop', ascending = False)
# Out:
#                                       poop
# nbrhood_name
# Tenderloin                        0.041891
# South of Market                   0.013928
# Downtown                          0.011659
# Inner Mission                     0.008183
# Van Ness/Civic Center             0.006966
# Duboce Triangle                   0.006140
# Hayes Valley                      0.005260
# Miraloma Park                     0.004612
# Yerba Buena                       0.004369
# Silver Terrace                    0.004303
# Eureka Valley / Dolores Heights   0.004014
# Portola                           0.003568
# Financial District/Barbary Coast  0.003176
# Haight Ashbury                    0.003135
# Nob Hill                          0.002914
# Telegraph Hill                    0.002842
# Noe Valley                        0.002819
# Corona Heights                    0.002275
# Westwood Park                     0.001712
# Outer Sunset                      0.001444
# Lone Mountain                     0.001375
# Bayview                           0.001349
# South Beach                       0.001341
# Buena Vista Park/Ashbury Heights  0.001276
# Inner Richmond                    0.001231
# Presidio Heights                  0.001214
# North Panhandle                   0.001206
# North Beach                       0.001182
# West Portal                       0.001141
# Bernal Heights                    0.001131
# ...                                    ...
# Lakeside                          0.000576
# Potrero Hill                      0.000571
# Visitacion Valley                 0.000562
# North Waterfront                  0.000560
# Diamond Heights                   0.000538
# Forest Hills Extension            0.000514
# Midtown Terrace                   0.000514
# Forest Hill                       0.000514
# Monterey Heights                  0.000500
# Mission Terrace                   0.000489
# Merced Manor                      0.000489
# 809260             5      5     0       0       1    ...          NaN
# 809261             5      5     6       0       1    ...          NaN
# 809262             5      5    12       0       1    ...          NaN
# 809263             5      5    18       0       1    ...          NaN
# 809264             6      5     0       0       1    ...          NaN
# 809265             6      5     6       0       1    ...          NaN
# ...              ...    ...   ...     ...     ...    ...          ...
# 9456514            0      4    18       0       1    ...          NaN
# 9456515            1      4     0       0       1    ...          NaN
# 9456516            1      4     6       0       1    ...          NaN
# 9456517            1      4    12       0       1    ...          NaN
# 9456518            1      4    18       0       1    ...          NaN
# 9456519            2      4     0       0       1    ...          NaN
# 9456520            2      4     6       0       1    ...          NaN
# 9456521            2      4    12       0       1    ...          NaN
# 9456522            2      4    18       0       1    ...          NaN
# 9456523            3      4     0       0       1    ...          NaN
# 9456524            3      4     6       0       1    ...          NaN
# 9456525            3      4    12       0       1    ...          NaN
# 9456526            3      4    18       0       1    ...          NaN
# 9456527            4      4     0       0       1    ...          NaN
# 9456528            4      4     6       0       1    ...          NaN
# 9456529            4      4    12       0       1    ...          NaN
# 9456530            4      4    18       0       1    ...          NaN
# 9456531            5      4     0       0       1    ...          NaN
# 9456532            5      4     6       0       1    ...          NaN
# 9456533            5      4    12       0       1    ...          NaN
# 9456534            5      4    18       0       1    ...          NaN
# 9456535            6      4     0       0       1    ...          NaN
# 9456536            6      4     6       0       1    ...          NaN
# 9456537            6      4    12       0       1    ...          NaN
# 9456538            6      4    18       0       1    ...          NaN
# 9456539            0      4     0       0       1    ...          NaN
# 9456540            0      4     6       0       1    ...          NaN
# 9456541            0      4    12       0       1    ...          NaN
# 9456542            0      4    18       0       1    ...          NaN
# 9456543            1      5     0       0       1    ...          NaN
#
#          UNIVPROX  SIGNALIZED  PKGMETERS  MAXPCTSLPE  MODEL6_VOL  HH_PEDMODE  \
# 809236        NaN         NaN        NaN         NaN         NaN         NaN
# 809237        NaN         NaN        NaN         NaN         NaN         NaN
# 809238        NaN         NaN        NaN         NaN         NaN         NaN
# 809239        NaN         NaN        NaN         NaN         NaN         NaN
# 809240        NaN         NaN        NaN         NaN         NaN         NaN
# 809241        NaN         NaN        NaN         NaN         NaN         NaN
# 809242        NaN         NaN        NaN         NaN         NaN         NaN
# 809243        NaN         NaN        NaN         NaN         NaN         NaN
# 809244        NaN         NaN        NaN         NaN         NaN         NaN
# 809245        NaN         NaN        NaN         NaN         NaN         NaN
# 809246        NaN         NaN        NaN         NaN         NaN         NaN
# 809247        NaN         NaN        NaN         NaN         NaN         NaN
# 809248        NaN         NaN        NaN         NaN         NaN         NaN
# 809249        NaN         NaN        NaN         NaN         NaN         NaN
# 809250        NaN         NaN        NaN         NaN         NaN         NaN
# 809251        NaN         NaN        NaN         NaN         NaN         NaN
# 809252        NaN         NaN        NaN         NaN         NaN         NaN
# 809253        NaN         NaN        NaN         NaN         NaN         NaN
# 809254        NaN         NaN        NaN         NaN         NaN         NaN
# 809255        NaN         NaN        NaN         NaN         NaN         NaN
# 809256        NaN         NaN        NaN         NaN         NaN         NaN
# 809257        NaN         NaN        NaN         NaN         NaN         NaN
# 809258        NaN         NaN        NaN         NaN         NaN         NaN
# 809259        NaN         NaN        NaN         NaN         NaN         NaN
# 809260        NaN         NaN        NaN         NaN         NaN         NaN
# 809261        NaN         NaN        NaN         NaN         NaN         NaN
# 809262        NaN         NaN        NaN         NaN         NaN         NaN
# 809263        NaN         NaN        NaN         NaN         NaN         NaN
# 809264        NaN         NaN        NaN         NaN         NaN         NaN
# 809265        NaN         NaN        NaN         NaN         NaN         NaN
# ...           ...         ...        ...         ...         ...         ...
# 9456514       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456515       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456516       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456517       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456518       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456519       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456520       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456521       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456522       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456523       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456524       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456525       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456526       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456527       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456528       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456529       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456530       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456531       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456532       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456533       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456534       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456535       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456536       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456537       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456538       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456539       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456540       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456541       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456542       0.0         0.0        0.0         4.0   1826830.0      1697.0
# 9456543       0.0         0.0        0.0         4.0   1826830.0      1697.0
#
#          PCOL_04_09  PCOL_RATE  HH_income
# 809236          NaN        NaN      87500
# 809237          NaN        NaN      87500
# 809238          NaN        NaN      87500
# 809239          NaN        NaN      87500
# 809240          NaN        NaN      87500
# 809241          NaN        NaN      87500
# 809242          NaN        NaN      87500
# 809243          NaN        NaN      87500
# 809244          NaN        NaN      87500
# 809245          NaN        NaN      87500
# 809246          NaN        NaN      87500
# 809247          NaN        NaN      87500
# 809248          NaN        NaN      87500
# 809249          NaN        NaN      87500
# 809250          NaN        NaN      87500
# 809251          NaN        NaN      87500
# 809252          NaN        NaN      87500
# 809253          NaN        NaN      87500
# 809254          NaN        NaN      87500
# 809255          NaN        NaN      87500
# 809256          NaN        NaN      87500
# 809257          NaN        NaN      87500
# 809258          NaN        NaN      87500
# 809259          NaN        NaN      87500
# 809260          NaN        NaN      87500
# 809261          NaN        NaN      87500
# 809262          NaN        NaN      87500
# 809263          NaN        NaN      87500
# 809264          NaN        NaN      87500
# 809265          NaN        NaN      87500
# ...             ...        ...        ...
# 9456514         0.0        0.0     117759
# 9456515         0.0        0.0     117759
# 9456516         0.0        0.0     117759
# 9456517         0.0        0.0     117759
# 9456518         0.0        0.0     117759
# 9456519         0.0        0.0     117759
# 9456520         0.0        0.0     117759
# 9456521         0.0        0.0     117759
# 9456522         0.0        0.0     117759
# 9456523         0.0        0.0     117759
# 9456524         0.0        0.0     117759
# 9456525         0.0        0.0     117759
# 9456526         0.0        0.0     117759
# 9456527         0.0        0.0     117759
# 9456528         0.0        0.0     117759
# 9456529         0.0        0.0     117759
# 9456530         0.0        0.0     117759
# 9456531         0.0        0.0     117759
# 9456532         0.0        0.0     117759
# 9456533         0.0        0.0     117759
# 9456534         0.0        0.0     117759
# 9456535         0.0        0.0     117759
# 9456536         0.0        0.0     117759
# 9456537         0.0        0.0     117759
# 9456538         0.0        0.0     117759
# 9456539         0.0        0.0     117759
# 9456540         0.0        0.0     117759
# 9456541         0.0        0.0     117759
# 9456542         0.0        0.0     117759
# 9456543         0.0        0.0     117759
#
# [1685399 rows x 136 columns]
